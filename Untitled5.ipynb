# %%
import pandas as pd

# %%
df= pd.read_csv("/content/drive/MyDrive/mp1 (1)/youth_smoking_drug_data_10000_rows_expanded.csv")

# %%
df.head()
# Out:
#    Year Age_Group  Gender  Smoking_Prevalence  Drug_Experimentation  \
# 0  2024     15-19    Both               18.85                 32.40
# 1  2024     10-14  Female               34.88                 41.57
# 2  2023     10-14    Both               42.00                 56.80
# 3  2024     40-49    Both               33.75                 42.90
# 4  2023     15-19    Male               47.90                 39.62
#
#   Socioeconomic_Status  Peer_Influence School_Programs  Family_Background  \
# 0                 High               5             Yes                  1
# 1                 High               6             Yes                 10
# 2                 High               6             Yes                  2
# 3               Middle              10              No                  9
# 4                 High               1              No                  2
#
#    Mental_Health Access_to_Counseling  Parental_Supervision  \
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for Gender, d in df.head().groupby('Gender'):
    ax.scatter(d['Year'], d['Smoking_Prevalence'], label=Gender)

plt.legend(loc='upper left')
plt.title('Sebaran Data Smoking Prevalence')
plt.xlabel('year')
plt.ylabel('Smoking Prevalence')
plt.grid(True)
plt.show()

# %%
import numpy as np

x_train = np.array(df.head() [['Year', 'Smoking_Prevalence']])
y_train = np.array(df.head() ['Gender'])

print(f'x_train:\n{x_train}\n')
print(f'y_train:{y_train}')
# Out:
# x_train:
# [[2024.     18.85]
#  [2024.     34.88]
#  [2023.     42.  ]
#  [2024.     33.75]
#  [2023.     47.9 ]]
#
# y_train:['Both' 'Female' 'Both' 'Both' 'Male']

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
print(f'y_train:\n{y_train}')
# Out:
# y_train:
# [[1 0 0]
#  [0 1 0]
#  [1 0 0]
#  [1 0 0]
#  [0 0 1]]

# %%
y_train = y_train.flatten()
print(f'y_train:\n{y_train}')
# Out:
# y_train:
# [1 0 0 0 1 0 1 0 0 1 0 0 0 0 1]

# %%
Year = 2023
Smoking_Prevalence = 18.85
x_new = np.array([Year,Smoking_Prevalence ]).reshape(1, -1)
x_new
# Out:
# array([[2023.  ,   18.85]])

# %%
y_new = model.predict(x_new)
y_new

# %%
lb.inverse_transform(x_new)
# Out:
# array(['Both'], dtype='<U6')

# %%
fig, ax = plt.subplots()
for Gender, d in df.head().groupby('Gender'):
  ax.scatter(d['Year'],d['Smoking_Prevalence'], label=Gender)

plt.scatter(Year,
            Smoking_Prevalence,
            marker='s',
            color='red',
            label='misterius')

plt.legend(loc='upper left')
plt.title('Sebaran Data Smoking Prevalence')
plt.xlabel('Year')
plt.ylabel('Smoking Prevalence')
plt.grid(True)
plt.show()

# %%
misterius = np.array([Year, Smoking_Prevalence])
misterius
# Out:
# array([2023.  ,   18.85])

# %%
x_train
# Out:
# array([[2024.  ,   18.85],
#        [2024.  ,   34.88],
#        [2023.  ,   42.  ],
#        [2024.  ,   33.75],
#        [2023.  ,   47.9 ]])

# %%
y_train
# Out:
# array([1, 0, 0, 0, 1, 0, 1, 0, 0, 1, 0, 0, 0, 0, 1])

# %%
from scipy.spatial.distance import euclidean

Drug_Experimentation = [euclidean(misterius, d) for d in x_train]
Drug_Experimentation
# Out:
# [1.0, 16.06116122825495, 23.15, 14.933519344079611, 29.049999999999997]

# %%
x_test = np.array([[50.1000,65], [70.8730, 96], [56,52], [169, 67]])
y_test = ib.transform(np.array(['1', '2', '0', '1'])).flatten()

print(f'x_test:\n{x_test}\n')
print(f'y_test: {y_test}')

# %%
y_pred = model.pradict(x_test)
y_pred

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_pred)
print(f'F1-score: {f1}')

# %%
from sklearn.metrics import classification_report
classification_report = classification_report(y_test, y_pred)
print(f'Classification Report:\n{classification_report}')
